# %%
import refinitiv.dataplatform.eikon as ek
ek.set_app_key('<APP Key>')
import pandas as pd

# %%
chain, e = ek.get_data('0#LKBFREURMBMK=', ['CF_DATE'])
chain
# Out:
#        Instrument     CF_DATE
# 0    ISSUE/METHOD        <NA>
# 1    LKBFREURMBMK        <NA>
# 2    LKBFREURM1Y=  2023-03-21
# 3    LKBFREURM2Y=  2023-03-21
# 4    LKBFREURM3Y=  2023-03-21
# 5    LKBFREURM4Y=  2023-03-21
# 6    LKBFREURM5Y=  2023-03-21
# 7    LKBFREURM6Y=  2023-03-21
# 8    LKBFREURM7Y=  2023-03-21
# 9    LKBFREURM8Y=  2023-03-21
# 10   LKBFREURM9Y=  2023-03-21
# 11  LKBFREURM10Y=  2023-03-21
# 12  LKBFREURM12Y=  2023-03-21
# 13  LKBFREURM15Y=  2023-03-21
# 14  LKBFREURM20Y=  2023-03-21
# 15  LKBFREURM25Y=  2023-03-21
# 16  LKBFREURM30Y=  2023-03-21

# %%
date = '2022-06-30'
instruments = list(chain['Instrument'])[2:]
curve,e = ek.get_data(instruments, ['TR.DEFAULTPROBABILITY', 'TR.SWAPSPREAD', 'TR.PARYIELD', 'TR.ZEROYIELD', 'TR.ZSPREAD'],{'SDate': date, 'EDate': date})
curve
# Out:
#        Instrument  Default Probability  Swap Spread  Par Yield  Zero Yield  \
# 0    LKBFREURM1Y=               0.1804         -8.0      0.756      0.7561
# 1    LKBFREURM2Y=               0.2026         -2.7      1.336      1.3399
# 2    LKBFREURM3Y=               0.4049          4.0      1.584      1.5911
# 3    LKBFREURM4Y=               0.4412          4.5      1.714       1.723
# 4    LKBFREURM5Y=               0.3574          2.9      1.807      1.8181
# 5    LKBFREURM6Y=               0.3314          2.1       1.89      1.9043
# 6    LKBFREURM7Y=               0.3921          2.5      1.972      1.9894
# 7    LKBFREURM8Y=               0.4951          3.1      2.053      2.0751
# 8    LKBFREURM9Y=               0.6672          4.1      2.134      2.1618
# 9   LKBFREURM10Y=               0.9185          5.5      2.215      2.2495
# 10  LKBFREURM12Y=               1.8935         10.6      2.375      2.4275
# 11  LKBFREURM15Y=                 <NA>         <NA>       <NA>        <NA>
# 12  LKBFREURM20Y=                 <NA>         <NA>       <NA>        <NA>
# 13  LKBFREURM25Y=                 <NA>         <NA>       <NA>        <NA>
# 14  LKBFREURM30Y=                 <NA>         <NA>       <NA>        <NA>
#
#     Z Spread
# 0       15.3
# 1       10.6
# 2       13.9
# 3       12.5
# 4        9.5
# 5        8.4
# 6        8.7
# 7        9.3
# 8       10.4
# 9       12.1
# 10      17.3
# 11      <NA>
# 12      <NA>
# 13      <NA>
# 14      <NA>

# %%
curve.to_excel("Covered_Bond_Curve.xlsx")
